# %%
# %load_ext autoreload
# %autoreload 2

import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

sns.set_style('whitegrid')

sys.path.append("../")
from utility.ar1 import AR1
from utility.hmm1 import HMM1
from utility.ar import AR

# %%
plt.plot(np.linspace(-10, 10, 1000), stats.cauchy(loc=0, scale=0.707).pdf(np.linspace(-10, 10, 1000)))

# %%
phi = 0.6
s = 1
v = s * (1-phi**2)
w = 1

hmm1 = HMM1(phi=phi, v_var=v, w_var=w)

# %%
data = hmm1.simulate(0, length=200)

# %%
data.plot(alpha=0.7, figsize=(20,5))
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x=data['xs'], y=data['ys'])
# Out:
# <AxesSubplot: xlabel='xs', ylabel='ys'>
