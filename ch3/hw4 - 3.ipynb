# %%
# %load_ext autoreload
# %autoreload 2

import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

sns.set_style('whitegrid')

sys.path.append("../")
from utility.mixture_normal import MixtureNormal

# %%
mn = MixtureNormal(qs=(0.4,0.4,0.2), ms=(-2,2,3), ws=(1,0.5,0.25))

# %%
mn.qs
# Out:
# array([0.4, 0.4, 0.2])

# %%
sns.kdeplot(mn.sample(100000))
# Out:
# <AxesSubplot: ylabel='Density'>
